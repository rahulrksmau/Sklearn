# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
train = pd.read_csv('train_modified.csv')
test = pd.read_csv('test_modified.csv')

# %%
print (train.info())
print (test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87020 entries, 0 to 87019
# Data columns (total 52 columns):
# Unnamed: 0                    87020 non-null int64
# Disbursed                     87020 non-null float64
# Existing_EMI                  87020 non-null float64
# ID                            87020 non-null object
# Loan_Amount_Applied           87020 non-null float64
# Loan_Tenure_Applied           87020 non-null float64
# Monthly_Income                87020 non-null int64
# Var4                          87020 non-null int64
# Var5                          87020 non-null int64
# Age                           87020 non-null int64
# EMI_Loan_Submitted_Missing    87020 non-null int64
# Interest_Rate_New             87020 non-null int64
# Loan_Tenure_Submitted_New     87020 non-null int64
# Loan_Amount_Submitted_New     87020 non-null int64
# Processing_Fee_New            87020 non-null int64
# Device_Type_0                 87020 non-null int64
# ...

# %%
#Model importing Liner Regression
from sklearn.linear_model import LogisticRegression

#splitting train data into X_train,X_test,y_train,y_test , For accuracy check
from sklearn.model_selection import train_test_split
from sklearn.metrics import  accuracy_score

# %%
#y = train['Disbursed']
#X = train.drop(['Disbursed','ID'], axis=1, inplace=True)
X= train
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87020 entries, 0 to 87019
# Data columns (total 50 columns):
# Unnamed: 0                    87020 non-null int64
# Existing_EMI                  87020 non-null float64
# Loan_Amount_Applied           87020 non-null float64
# Loan_Tenure_Applied           87020 non-null float64
# Monthly_Income                87020 non-null int64
# Var4                          87020 non-null int64
# Var5                          87020 non-null int64
# Age                           87020 non-null int64
# EMI_Loan_Submitted_Missing    87020 non-null int64
# Interest_Rate_New             87020 non-null int64
# Loan_Tenure_Submitted_New     87020 non-null int64
# Loan_Amount_Submitted_New     87020 non-null int64
# Processing_Fee_New            87020 non-null int64
# Device_Type_0                 87020 non-null int64
# Device_Type_1                 87020 non-null int64
# Filled_Form_0                 87020 non-null int64
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=22, test_size=0.40)

# %%
# logical Regression model creation 
model1 = LogisticRegression()

# %%
#model training 
model1.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
model1.score(X,y)
test.drop(['ID', 'Disbursed'], axis=1, inplace=True)

# %%
# predicting the solution i.e. Disbursed of test Dataset
predict = model1.predict(test)
test['Disbursed'] = predict

# %%
test.head()
# Out:
#    Unnamed: 0  Existing_EMI  Loan_Amount_Applied  Loan_Tenure_Applied  \
# 0       87020           0.0             100000.0                  3.0
# 1       87021           0.0                  0.0                  0.0
# 2       87022           0.0             300000.0                  2.0
# 3       87023           0.0                  0.0                  0.0
# 4       87024        5000.0             100000.0                  1.0
#
#    Monthly_Income  Var4  Var5  Age  EMI_Loan_Submitted_Missing  \
# 0           21500     3     3   28                           0
# 1           42000     5     8   35                           0
# 2           10000     1     0   26                           1
# 3           14650     1     0   24                           1
# 4           23400     1     0   28                           1
#
#    Interest_Rate_New    ...      Var2_3  Var2_4  Var2_5  Var2_6  \
# 0                  0    ...           0       0       0       0
# ...

# %%
train.head()
# Out:
#    Unnamed: 0  Existing_EMI  Loan_Amount_Applied  Loan_Tenure_Applied  \
# 0           0           0.0             300000.0                  5.0
# 1           1           0.0             200000.0                  2.0
# 2           2           0.0             600000.0                  4.0
# 3           3           0.0            1000000.0                  5.0
# 4           4       25000.0             500000.0                  2.0
#
#    Monthly_Income  Var4  Var5  Age  EMI_Loan_Submitted_Missing  \
# 0           20000     1     0   37                           1
# 1           35000     3    13   30                           0
# 2           22500     1     0   34                           1
# 3           35000     3    10   28                           1
# 4          100000     3    17   31                           1
#
#    Interest_Rate_New    ...     Var2_2  Var2_3  Var2_4  Var2_5  Var2_6  \
# 0                  1    ...          0       0       0       0       1
# ...

# %%
model1.score(X,y)
# Out:
# 0.98537117903930127
